# %% [markdown]
# # Bureau of Economic Analysis (BEA) API Data Retrieval for  QGIS Plugin
#
# BEA API documentation is available [here](https://apps.bea.gov/api/_pdf/bea_web_service_api_user_guide.pdf)

# %%
import requests
import pandas as pd
import config 

api_key = config.bea_key  #file with API key

# %% [markdown]
# #### The BEA API request will contain the following URL (or a similar URL) with its own required parameters
#
# https://apps.bea.gov/api/data/UserID=Your36CharacterKey&method=GetData&datasetname=Regional&TableName=CAINC1&LineCode=1&Year=2012,2013&GeoFips=COUNTY&ResultFormat=json
#
# *Note that the parameters will change depending on the dataset being requested

# %% [markdown]
# ### Data request for the "Personal Income" table (CAINC1 | 1969 ->)  found on the Regional dataset

# %%
#Components of request: 

base = f'https://www.bea.gov/api/data/?&UserID={config.bea_key}'
dset = '&method=GetData&datasetname=Regional'
tbl = '&TableName=CAINC1' 
freq = '&Frequency=Y'
lncode = '&LineCode=1'  #line code found on the second request
yr = '&Year= 2015' #change year accordingly 
geofips = '&GeoFips=STATE'
fmt = '&ResultFormat=json'
url = f'{base}{dset}&TableName={tbl}{freq}{lncode}{yr}{geofips}{fmt}'

# %%
# Request data
r = requests.get(url).json()['BEAAPI']['Results']

# %%
r
# Out:
# {'Statistic': 'Personal income',
#  'UnitOfMeasure': 'Thousands of dollars',
#  'PublicTable': 'CAINC1 Personal income (thousands of dollars)',
#  'UTCProductionTime': '2020-05-18T21:30:53.353',
#  'NoteRef': ' ',
#  'Dimensions': [{'Name': 'Code', 'DataType': 'string', 'IsValue': '0'},
#   {'Name': 'GeoFips', 'DataType': 'string', 'IsValue': '0'},
#   {'Name': 'GeoName', 'DataType': 'string', 'IsValue': '0'},
#   {'Name': 'TimePeriod', 'DataType': 'string', 'IsValue': '0'},
#   {'Name': 'DataValue', 'DataType': 'numeric', 'IsValue': '1'},
#   {'Name': 'CL_UNIT', 'DataType': 'string', 'IsValue': '0'},
#   {'Name': 'UNIT_MULT', 'DataType': 'numeric', 'IsValue': '0'}],
#  'Data': [{'Code': 'CAINC1-1',
#    'GeoFips': '00000',
#    'GeoName': 'United States',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '15,709,242,000'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '01000',
#    'GeoName': 'Alabama',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '187,544,435'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '02000',
#    'GeoName': 'Alaska',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '42,469,900'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '04000',
#    'GeoName': 'Arizona',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '271,132,762'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '05000',
#    'GeoName': 'Arkansas',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '117,180,599'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '06000',
#    'GeoName': 'California',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '2,171,947,376'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '08000',
#    'GeoName': 'Colorado',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '284,233,907'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '09000',
#    'GeoName': 'Connecticut',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '244,982,293'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '10000',
#    'GeoName': 'Delaware',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '45,150,728'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '11000',
#    'GeoName': 'District of Columbia',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '50,940,464'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '12000',
#    'GeoName': 'Florida',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '915,895,494'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '13000',
#    'GeoName': 'Georgia',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '424,356,326'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '15000',
#    'GeoName': 'Hawaii',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '70,384,467'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '16000',
#    'GeoName': 'Idaho',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '65,825,237'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '17000',
#    'GeoName': 'Illinois',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '662,760,794'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '18000',
#    'GeoName': 'Indiana',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '281,691,638'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '19000',
#    'GeoName': 'Iowa',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '144,287,791'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '20000',
#    'GeoName': 'Kansas',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '137,868,251'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '21000',
#    'GeoName': 'Kentucky',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '173,025,584'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '200,748,457'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '23000',
#    'GeoName': 'Maine',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '57,947,719'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '24000',
#    'GeoName': 'Maryland',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '342,074,347'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '25000',
#    'GeoName': 'Massachusetts',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '432,102,283'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '26000',
#    'GeoName': 'Michigan',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '432,391,533'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '27000',
#    'GeoName': 'Minnesota',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '286,818,725'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '28000',
#    'GeoName': 'Mississippi',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '104,670,148'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '29000',
#    'GeoName': 'Missouri',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '261,666,491'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '30000',
#    'GeoName': 'Montana',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '44,831,039'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '31000',
#    'GeoName': 'Nebraska',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '95,687,428'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '32000',
#    'GeoName': 'Nevada',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '126,408,020'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '33000',
#    'GeoName': 'New Hampshire',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '73,212,417'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '34000',
#    'GeoName': 'New Jersey',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '542,097,272'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '35000',
#    'GeoName': 'New Mexico',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '79,973,393'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '36000',
#    'GeoName': 'New York',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '1,162,801,418'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '37000',
#    'GeoName': 'North Carolina',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '419,891,523'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '38000',
#    'GeoName': 'North Dakota',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '40,600,607'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '39000',
#    'GeoName': 'Ohio',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '515,138,454'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '40000',
#    'GeoName': 'Oklahoma',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '172,992,075'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '41000',
#    'GeoName': 'Oregon',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '181,491,700'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '42000',
#    'GeoName': 'Pennsylvania',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '644,119,451'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '44000',
#    'GeoName': 'Rhode Island',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '52,864,975'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '45000',
#    'GeoName': 'South Carolina',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '193,225,799'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '46000',
#    'GeoName': 'South Dakota',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '41,547,937'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '47000',
#    'GeoName': 'Tennessee',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '280,719,455'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '48000',
#    'GeoName': 'Texas',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '1,280,251,017'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '49000',
#    'GeoName': 'Utah',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '121,884,897'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '50000',
#    'GeoName': 'Vermont',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '30,998,720'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '51000',
#    'GeoName': 'Virginia',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '442,331,375'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '53000',
#    'GeoName': 'Washington',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '385,687,900'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '54000',
#    'GeoName': 'West Virginia',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '67,997,283'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '55000',
#    'GeoName': 'Wisconsin',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '268,947,729'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '56000',
#    'GeoName': 'Wyoming',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '33,442,367'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '91000',
#    'GeoName': 'New England',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '892,108,407'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '92000',
#    'GeoName': 'Mideast',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '2,787,183,680'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '93000',
#    'GeoName': 'Great Lakes',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '2,160,930,148'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '94000',
#    'GeoName': 'Plains',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '1,008,477,230'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '95000',
#    'GeoName': 'Southeast',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '3,527,586,478'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '96000',
#    'GeoName': 'Southwest',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '1,804,349,247'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '97000',
#    'GeoName': 'Rocky Mountain',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '550,217,447'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '98000',
#    'GeoName': 'Far West',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '2,978,389,363'}],
#  'Notes': [{'NoteRef': ' ',
#    'NoteText': 'Metropolitan Areas are defined (geographically delineated) by the Office of Management and Budget bulletin no. 18-04 issued September 14, 2018.'},
#   {'NoteRef': 'Note--',
#    'NoteText': 'All dollar estimates are in thousands of current dollars (not adjusted for inflation). Calculations are performed on unrounded data.'},
#   {'NoteRef': ' ',
#    'NoteText': 'Last updated: November 14, 2019-- new statistics for 2018; revised statistics for 1969-2017.'}]}

# %% [markdown]
# *Note that this request only inlcudes "LineCode 1" which is Personal Income. We will need a loop to gather all three LineCodes

# %% [markdown]
# #### In order to see what Linecodes or variables are avaialble on this table, we need to request them from the BEA
#
# The LineCode request URL will look something like this:
#
# https://apps.bea.gov/api/data/UserID=Your36CharacterKey&method=GetParameterValuesFiltered&datasetname=Regional&TargetParameter=LineCode&TableName=CAINC1&ResultFormat=json

# %%
#Components of LineCode request:

base = f'https://www.bea.gov/api/data/?&UserID={config.bea_key}'
dset = '&method=GetParameterValuesFiltered&datasetname=Regional'
param = '&TargetParameter=LineCode'
tbl = '&TableName=CAINC1' 
fmt = '&ResultFormat=json'
url = f'{base}{dset}&TableName={param}{tbl}{fmt}'

# %%
# Request LineCodes
ln = requests.get(url).json()['BEAAPI']['Results']

# %%
# LineCodes available as will show up as "Key"
ln
# Out:
# {'ParamValue': [{'Key': '1', 'Desc': '[CAINC1] Personal income'},
#   {'Key': '2', 'Desc': '[CAINC1] Population'},
#   {'Key': '3', 'Desc': '[CAINC1] Per capita personal income'}]}

# %% [markdown]
# We see that table CAINC1 has three different variables: personal income, population, and per capita personal income.

# %% [markdown]
# ### Data request for "Total Employment" table (CAEMP25N | 2001 ->)

# %% [markdown]
# Requesting the LineCodes for Total Employment

# %%
#Components of LineCode request:

base = f'https://www.bea.gov/api/data/?&UserID={config.bea_key}'
dset = '&method=GetParameterValuesFiltered&datasetname=Regional'
param = '&TargetParameter=LineCode'
tbl = '&TableName=CAEMP25N' 
fmt = '&ResultFormat=json'
url = f'{base}{dset}&TableName={param}{tbl}{fmt}'

# %%
ln2 = requests.get(url).json()['BEAAPI']['Results']

# %%
ln2
# Out:
# {'ParamValue': [{'Key': '10', 'Desc': '[CAEMP25N] Total employment'},
#   {'Key': '100',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Forestry, fishing, and related activities (NAICS:113-115)'},
#   {'Key': '1000',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Finance and insurance (NAICS:52)'},
#   {'Key': '1100',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Real estate and rental and leasing (NAICS:53)'},
#   {'Key': '1200',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Professional, scientific, and technical services (NAICS:54)'},
#   {'Key': '1300',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Management of companies and enterprises (NAICS:55)'},
#   {'Key': '1400',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Administrative and support and waste management and remediation services (NAICS:56)'},
#   {'Key': '1500',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Educational services (NAICS:61)'},
#   {'Key': '1600',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Health care and social assistance (NAICS:62)'},
#   {'Key': '1700',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Arts, entertainment, and recreation (NAICS:71)'},
#   {'Key': '1800',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Accommodation and food services (NAICS:72)'},
#   {'Key': '1900',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Other services (except government and government enterprises) (NAICS:81)'},
#   {'Key': '20', 'Desc': '[CAEMP25N] Wage and salary employment'},
#   {'Key': '200',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Mining, quarrying, and oil and gas extraction (NAICS:21)'},
#   {'Key': '2000',
#    'Desc': '[CAEMP25N] Employment: Government and government enterprises'},
#   {'Key': '2001',
#    'Desc': '[CAEMP25N] Govt. and govt. enterprises employment: Federal civilian'},
#   {'Key': '2002',
#    'Desc': '[CAEMP25N] Govt. and govt. enterprises employment: Military'},
#   {'Key': '2010',
#    'Desc': '[CAEMP25N] Govt. and govt. enterprises employment: State and local'},
#   {'Key': '2011',
#    'Desc': '[CAEMP25N] Govt. and govt. enterprises employment: State government'},
#   {'Key': '2012',
#    'Desc': '[CAEMP25N] Govt. and govt. enterprises employment: Local government'},
#   {'Key': '300',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Utilities (NAICS:22)'},
#   {'Key': '40', 'Desc': '[CAEMP25N] Proprietors employment'},
#   {'Key': '400',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Construction (NAICS:23)'},
#   {'Key': '50', 'Desc': '[CAEMP25N] Farm proprietors employment'},
#   {'Key': '500',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Manufacturing (NAICS:31-33)'},
#   {'Key': '60', 'Desc': '[CAEMP25N] Nonfarm proprietors employment'},
#   {'Key': '600',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Wholesale trade (NAICS:42)'},
#   {'Key': '70', 'Desc': '[CAEMP25N] Farm employment (NAICS:111-112)'},
#   {'Key': '700',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Retail trade (NAICS:44-45)'},
#   {'Key': '80', 'Desc': '[CAEMP25N] Nonfarm employment'},
#   {'Key': '800',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Transportation and warehousing (NAICS:48-49)'},
#   {'Key': '90', 'Desc': '[CAEMP25N] Private nonfarm employment'},
#   {'Key': '900',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Information (NAICS:51)'}]}

# %% [markdown]
# #### Creating the url for "total employment" (line code '10')
# Note that we are still using the same dataset "Regional".

# %%
#Components of request: 

base = f'https://www.bea.gov/api/data/?&UserID={config.bea_key}'
dset = '&method=GetData&datasetname=Regional'
tbl = '&TableName= CAEMP25N' 
freq = '&Frequency=Y'
lncode = '&LineCode=10'  #line code 
yr = '&Year= 2015' #change year accordingly 
geofips = '&GeoFips=STATE'
fmt = '&ResultFormat=json'
url = f'{base}{dset}&TableName={tbl}{freq}{lncode}{yr}{geofips}{fmt}'

# %%
# Request data
r2 = requests.get(url).json()['BEAAPI']['Results']

# %%
r2
# Out:
# {'Statistic': 'Total employment',
#  'UnitOfMeasure': 'Number of jobs',
#  'PublicTable': 'CAEMP25N Total employment (number of jobs)',
#  'UTCProductionTime': '2020-05-18T21:30:55.933',
#  'NoteRef': ' ',
#  'Dimensions': [{'Name': 'Code', 'DataType': 'string', 'IsValue': '0'},
#   {'Name': 'GeoFips', 'DataType': 'string', 'IsValue': '0'},
#   {'Name': 'GeoName', 'DataType': 'string', 'IsValue': '0'},
#   {'Name': 'TimePeriod', 'DataType': 'string', 'IsValue': '0'},
#   {'Name': 'DataValue', 'DataType': 'numeric', 'IsValue': '1'},
#   {'Name': 'CL_UNIT', 'DataType': 'string', 'IsValue': '0'},
#   {'Name': 'UNIT_MULT', 'DataType': 'numeric', 'IsValue': '0'}],
#  'Data': [{'Code': 'CAEMP25N-10',
#    'GeoFips': '00000',
#    'GeoName': 'United States',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '190,315,800'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '01000',
#    'GeoName': 'Alabama',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '2,586,885'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '02000',
#    'GeoName': 'Alaska',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '461,767'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '04000',
#    'GeoName': 'Arizona',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '3,548,174'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '05000',
#    'GeoName': 'Arkansas',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '1,610,779'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '06000',
#    'GeoName': 'California',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '22,686,455'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '08000',
#    'GeoName': 'Colorado',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '3,574,369'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '09000',
#    'GeoName': 'Connecticut',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '2,288,017'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '10000',
#    'GeoName': 'Delaware',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '568,879'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '11000',
#    'GeoName': 'District of Columbia',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '873,193'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '12000',
#    'GeoName': 'Florida',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '11,366,665'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '13000',
#    'GeoName': 'Georgia',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '5,832,372'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '15000',
#    'GeoName': 'Hawaii',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '901,206'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '16000',
#    'GeoName': 'Idaho',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '949,276'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '17000',
#    'GeoName': 'Illinois',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '7,748,883'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '18000',
#    'GeoName': 'Indiana',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '3,796,375'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '19000',
#    'GeoName': 'Iowa',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '2,059,398'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '20000',
#    'GeoName': 'Kansas',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '1,910,809'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '21000',
#    'GeoName': 'Kentucky',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '2,473,302'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '2,695,547'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '23000',
#    'GeoName': 'Maine',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '816,598'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '24000',
#    'GeoName': 'Maryland',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '3,602,938'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '25000',
#    'GeoName': 'Massachusetts',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '4,631,324'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '26000',
#    'GeoName': 'Michigan',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '5,501,054'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '27000',
#    'GeoName': 'Minnesota',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '3,662,971'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '28000',
#    'GeoName': 'Mississippi',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '1,568,187'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '29000',
#    'GeoName': 'Missouri',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '3,654,912'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '30000',
#    'GeoName': 'Montana',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '660,326'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '31000',
#    'GeoName': 'Nebraska',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '1,302,888'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '32000',
#    'GeoName': 'Nevada',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '1,664,121'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '33000',
#    'GeoName': 'New Hampshire',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '860,597'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '34000',
#    'GeoName': 'New Jersey',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '5,302,982'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '35000',
#    'GeoName': 'New Mexico',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '1,091,984'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '36000',
#    'GeoName': 'New York',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '12,099,078'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '37000',
#    'GeoName': 'North Carolina',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '5,695,077'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '38000',
#    'GeoName': 'North Dakota',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '597,475'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '39000',
#    'GeoName': 'Ohio',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '6,862,067'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '40000',
#    'GeoName': 'Oklahoma',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '2,286,956'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '41000',
#    'GeoName': 'Oregon',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '2,390,658'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '42000',
#    'GeoName': 'Pennsylvania',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '7,510,216'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '44000',
#    'GeoName': 'Rhode Island',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '627,000'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '45000',
#    'GeoName': 'South Carolina',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '2,636,675'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '46000',
#    'GeoName': 'South Dakota',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '592,665'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '47000',
#    'GeoName': 'Tennessee',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '3,858,802'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '48000',
#    'GeoName': 'Texas',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '16,413,328'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '49000',
#    'GeoName': 'Utah',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '1,866,146'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '50000',
#    'GeoName': 'Vermont',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '432,641'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '51000',
#    'GeoName': 'Virginia',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '5,060,545'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '53000',
#    'GeoName': 'Washington',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '4,198,931'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '54000',
#    'GeoName': 'West Virginia',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '903,866'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '55000',
#    'GeoName': 'Wisconsin',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '3,624,387'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '56000',
#    'GeoName': 'Wyoming',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '406,054'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '91000',
#    'GeoName': 'New England',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '9,656,177'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '92000',
#    'GeoName': 'Mideast',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '29,957,286'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '93000',
#    'GeoName': 'Great Lakes',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '27,532,766'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '94000',
#    'GeoName': 'Plains',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '13,781,118'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '95000',
#    'GeoName': 'Southeast',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '46,288,702'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '96000',
#    'GeoName': 'Southwest',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '23,340,442'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '97000',
#    'GeoName': 'Rocky Mountain',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '7,456,171'},
#   {'Code': 'CAEMP25N-10',
#    'GeoFips': '98000',
#    'GeoName': 'Far West',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '32,303,138'}],
#  'Notes': [{'NoteRef': ' ',
#    'NoteText': 'Metropolitan Areas are defined (geographically delineated) by the Office of Management and Budget bulletin no. 18-04 issued September 14, 2018.'},
#   {'NoteRef': ' ',
#    'NoteText': 'Last updated: November 14, 2019-- new statistics for 2018; revised statistics for 2001-2017.'}]}

# %% [markdown]
# ### Data request for "Total Employment" table (CAEMP25S | 1969-2000)

# %%
#Components of LineCode request for CAEMP25S:

base = f'https://www.bea.gov/api/data/?&UserID={config.bea_key}'
dset = '&method=GetParameterValuesFiltered&datasetname=Regional'
param = '&TargetParameter=LineCode'
tbl = '&TableName=CAEMP25S' 
fmt = '&ResultFormat=json'
url = f'{base}{dset}&TableName={param}{tbl}{fmt}'

# %%
ln3 = requests.get(url).json()['BEAAPI']['Results']

# %%
ln3
# Out:
# {'ParamValue': [{'Key': '10', 'Desc': '[CAEMP25S] Total employment'},
#   {'Key': '100',
#    'Desc': '[CAEMP25S] Private nonfarm earnings: Agricultural services, forestry, and fishing (SIC:[07-09])'},
#   {'Key': '20', 'Desc': '[CAEMP25S] Wage and salary employment'},
#   {'Key': '200',
#    'Desc': '[CAEMP25S] Private nonfarm employment: Mining (SIC:B)'},
#   {'Key': '300',
#    'Desc': '[CAEMP25S] Private nonfarm employment: Construction (SIC:C)'},
#   {'Key': '40', 'Desc': '[CAEMP25S] Proprietors employment'},
#   {'Key': '400',
#    'Desc': '[CAEMP25S] Private nonfarm employment: Manufacturing (SIC:D)'},
#   {'Key': '50', 'Desc': '[CAEMP25S] Farm proprietors employment'},
#   {'Key': '500',
#    'Desc': '[CAEMP25S] Private nonfarm employment: Transportation and public utilities (SIC:E)'},
#   {'Key': '60', 'Desc': '[CAEMP25S] Nonfarm proprietors employment'},
#   {'Key': '610',
#    'Desc': '[CAEMP25S] Private nonfarm employment: Wholesale trade (SIC:F)'},
#   {'Key': '620',
#    'Desc': '[CAEMP25S] Private nonfarm employment: Retail trade (SIC:G)'},
#   {'Key': '70', 'Desc': '[CAEMP25S] Farm employment (SIC:[01-02])'},
#   {'Key': '700',
#    'Desc': '[CAEMP25S] Private nonfarm employment: Finance, insurance, and real estate (SIC:H)'},
#   {'Key': '80', 'Desc': '[CAEMP25S] Nonfarm employment'},
#   {'Key': '800',
#    'Desc': '[CAEMP25S] Private nonfarm employment: Services (SIC:I)'},
#   {'Key': '90', 'Desc': '[CAEMP25S] Private nonfarm employment'},
#   {'Key': '900',
#    'Desc': '[CAEMP25S] Employment: Government and government enterprises'},
#   {'Key': '910',
#    'Desc': '[CAEMP25S] Govt. and govt. enterprises employment: Federal civilian'},
#   {'Key': '920',
#    'Desc': '[CAEMP25S] Govt. and govt. enterprises employment: Military'},
#   {'Key': '930',
#    'Desc': '[CAEMP25S] Govt. and govt. enterprises employment: State and local'},
#   {'Key': '931',
#    'Desc': '[CAEMP25S] Govt. and govt. enterprises employment: State government'},
#   {'Key': '932',
#    'Desc': '[CAEMP25S] Govt. and govt. enterprises employment: Local government'}]}

# %% [markdown]
# #### Data request

# %%
#Components of request: 

base = f'https://www.bea.gov/api/data/?&UserID={config.bea_key}'
dset = '&method=GetData&datasetname=Regional'
tbl = '&TableName= CAEMP25S' 
freq = '&Frequency=Y'
lncode = '&LineCode=10'  #line code 
yr = '&Year= 2000' #change year accordingly (must be 2000 or less)
geofips = '&GeoFips=STATE'
fmt = '&ResultFormat=json'
url = f'{base}{dset}&TableName={tbl}{freq}{lncode}{yr}{geofips}{fmt}'

# %%
#request data
r3 = requests.get(url).json()['BEAAPI']['Results']

# %%
r3
# Out:
# {'Statistic': 'Total employment',
#  'UnitOfMeasure': 'Number of jobs',
#  'PublicTable': 'CAEMP25S Total employment (number of jobs)',
#  'UTCProductionTime': '2020-05-18T21:31:05.603',
#  'NoteRef': ' ',
#  'Dimensions': [{'Name': 'Code', 'DataType': 'string', 'IsValue': '0'},
#   {'Name': 'GeoFips', 'DataType': 'string', 'IsValue': '0'},
#   {'Name': 'GeoName', 'DataType': 'string', 'IsValue': '0'},
#   {'Name': 'TimePeriod', 'DataType': 'string', 'IsValue': '0'},
#   {'Name': 'DataValue', 'DataType': 'numeric', 'IsValue': '1'},
#   {'Name': 'CL_UNIT', 'DataType': 'string', 'IsValue': '0'},
#   {'Name': 'UNIT_MULT', 'DataType': 'numeric', 'IsValue': '0'}],
#  'Data': [{'Code': 'CAEMP25S-10',
#    'GeoFips': '00000',
#    'GeoName': 'United States',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '165,370,800'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '01000',
#    'GeoName': 'Alabama',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '2,392,225'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '02000',
#    'GeoName': 'Alaska',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '389,734'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '04000',
#    'GeoName': 'Arizona',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '2,801,510'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '05000',
#    'GeoName': 'Arkansas',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '1,482,449'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '06000',
#    'GeoName': 'California',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '19,228,895'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '08000',
#    'GeoName': 'Colorado',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '2,918,002'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '09000',
#    'GeoName': 'Connecticut',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '2,118,177'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '10000',
#    'GeoName': 'Delaware',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '503,458'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '11000',
#    'GeoName': 'District of Columbia',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '735,304'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '12000',
#    'GeoName': 'Florida',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '8,881,279'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '13000',
#    'GeoName': 'Georgia',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '4,860,810'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '15000',
#    'GeoName': 'Hawaii',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '749,439'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '16000',
#    'GeoName': 'Idaho',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '776,910'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '17000',
#    'GeoName': 'Illinois',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '7,357,491'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '18000',
#    'GeoName': 'Indiana',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '3,648,148'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '19000',
#    'GeoName': 'Iowa',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '1,915,254'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '20000',
#    'GeoName': 'Kansas',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '1,760,312'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '21000',
#    'GeoName': 'Kentucky',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '2,306,481'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '2,388,668'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '23000',
#    'GeoName': 'Maine',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '784,039'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '24000',
#    'GeoName': 'Maryland',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '3,092,125'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '25000',
#    'GeoName': 'Massachusetts',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '4,070,320'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '26000',
#    'GeoName': 'Michigan',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '5,621,494'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '27000',
#    'GeoName': 'Minnesota',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '3,330,936'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '28000',
#    'GeoName': 'Mississippi',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '1,476,295'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '29000',
#    'GeoName': 'Missouri',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '3,470,846'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '30000',
#    'GeoName': 'Montana',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '552,690'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '31000',
#    'GeoName': 'Nebraska',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '1,173,756'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '32000',
#    'GeoName': 'Nevada',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '1,254,358'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '33000',
#    'GeoName': 'New Hampshire',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '783,545'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '34000',
#    'GeoName': 'New Jersey',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '4,748,598'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '35000',
#    'GeoName': 'New Mexico',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '964,919'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '36000',
#    'GeoName': 'New York',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '10,424,526'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '37000',
#    'GeoName': 'North Carolina',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '4,891,957'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '38000',
#    'GeoName': 'North Dakota',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '440,643'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '39000',
#    'GeoName': 'Ohio',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '6,789,300'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '40000',
#    'GeoName': 'Oklahoma',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '1,994,373'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '41000',
#    'GeoName': 'Oregon',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '2,092,153'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '42000',
#    'GeoName': 'Pennsylvania',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '6,905,286'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '44000',
#    'GeoName': 'Rhode Island',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '582,589'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '45000',
#    'GeoName': 'South Carolina',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '2,279,819'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '46000',
#    'GeoName': 'South Dakota',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '512,377'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '47000',
#    'GeoName': 'Tennessee',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '3,459,310'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '48000',
#    'GeoName': 'Texas',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '12,138,771'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '49000',
#    'GeoName': 'Utah',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '1,380,538'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '50000',
#    'GeoName': 'Vermont',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '400,963'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '51000',
#    'GeoName': 'Virginia',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '4,399,151'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '53000',
#    'GeoName': 'Washington',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '3,526,778'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '54000',
#    'GeoName': 'West Virginia',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '875,561'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '55000',
#    'GeoName': 'Wisconsin',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '3,413,585'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '56000',
#    'GeoName': 'Wyoming',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '324,653'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '91000',
#    'GeoName': 'New England',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '8,739,633'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '92000',
#    'GeoName': 'Mideast',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '26,409,297'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '93000',
#    'GeoName': 'Great Lakes',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '26,830,018'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '94000',
#    'GeoName': 'Plains',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '12,604,124'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '95000',
#    'GeoName': 'Southeast',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '39,694,005'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '96000',
#    'GeoName': 'Southwest',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '17,899,573'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '97000',
#    'GeoName': 'Rocky Mountain',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '5,952,793'},
#   {'Code': 'CAEMP25S-10',
#    'GeoFips': '98000',
#    'GeoName': 'Far West',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Number of jobs',
#    'UNIT_MULT': '0',
#    'DataValue': '27,241,357'}],
#  'Notes': [{'NoteRef': ' ',
#    'NoteText': 'Metropolitan Areas are defined (geographically delineated) by the Office of Management and Budget bulletin no. 18-04 issued September 14, 2018.'},
#   {'NoteRef': ' ',
#    'NoteText': 'Last updated: November 14, 2019-- revised statistics for 1969-2000.'}]}

# %% [markdown]
# ### Creating the loop for the line codes
